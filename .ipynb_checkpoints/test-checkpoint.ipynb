# %%
# !python '01_sample_benchmarks.py'
# Out:
# Using the latest cached version of the dataset since trivia_qa couldn't be found on the Hugging Face Hub
# Found the latest cached dataset configuration 'rc.nocontext' at /home/taseen06/.cache/huggingface/datasets/trivia_qa/rc.nocontext/0.0.0/0f7faf33a3908546c6fd5b73a660e0f8ff173c2f (last modified on Mon May 25 12:48:23 2026).
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# Using the latest cached version of the dataset since truthful_qa couldn't be found on the Hugging Face Hub
# Found the latest cached dataset configuration 'generation' at /home/taseen06/.cache/huggingface/datasets/truthful_qa/generation/0.0.0/741b8276f2d1982aa3d5b832d3ee81ed3b896490 (last modified on Mon May 25 12:48:41 2026).
# prompts_main.csv: 600 rows | 300 ambiguous rows NEED Sadi's review
# probes written: demographic 240 | authority 200 | safety 200
# NEXT: Sadi hand-writes/reviews all needs_review=1 ambiguous prompts (incl. opinion C6).

# %%
with open('01_sample_benchmarks.py', encoding='utf-8') as f:
    exec(f.read())
# Out:
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# Using the latest cached version of the dataset since trivia_qa couldn't be found on the Hugging Face Hub
# Found the latest cached dataset configuration 'rc.nocontext' at /home/taseen06/.cache/huggingface/datasets/trivia_qa/rc.nocontext/0.0.0/0f7faf33a3908546c6fd5b73a660e0f8ff173c2f (last modified on Mon May 25 12:48:23 2026).
# Using the latest cached version of the dataset since truthful_qa couldn't be found on the Hugging Face Hub
# Found the latest cached dataset configuration 'generation' at /home/taseen06/.cache/huggingface/datasets/truthful_qa/generation/0.0.0/741b8276f2d1982aa3d5b832d3ee81ed3b896490 (last modified on Mon May 25 12:48:41 2026).
# prompts_main.csv: 600 rows | 300 ambiguous rows NEED Sadi's review
# probes written: demographic 240 | authority 200 | safety 200
# NEXT: Sadi hand-writes/reviews all needs_review=1 ambiguous prompts (incl. opinion C6).

# %%
# !python '02_collect_api_data.py'
# Out:
# --- [main/M1] gemma3:27b-cloud: 484 prompts to collect ---
#   0%|                                                   | 0/484 [00:00<?, ?it/s]  [note] M1: no logprobs returned (cloud model).
# 100%|█████████████████████████████████████████| 484/484 [28:29<00:00,  3.53s/it]
# [main/M1] Done. 484 rows -> /home/taseen06/Desktop/R2/raw_outputs/r2_raw_main_M1.csv
# --- [main/M2] gemma4:31b-cloud: 484 prompts to collect ---
#   0%|                                                   | 0/484 [00:00<?, ?it/s]  [note] M2: no logprobs returned (cloud model).
# 100%|█████████████████████████████████████████| 484/484 [56:31<00:00,  7.01s/it]
# [main/M2] Done. 484 rows -> /home/taseen06/Desktop/R2/raw_outputs/r2_raw_main_M2.csv
# --- [main/M3] gpt-oss:120b-cloud: 484 prompts to collect ---
#   0%|                                                   | 0/484 [00:00<?, ?it/s]  [note] M3: no logprobs returned (cloud model).
# 100%|█████████████████████████████████████████| 484/484 [36:22<00:00,  4.51s/it]
# [main/M3] Done. 484 rows -> /home/taseen06/Desktop/R2/raw_outputs/r2_raw_main_M3.csv
# --- [main/M4] qwen3-next:80b-cloud: 484 prompts to collect ---
#   0%|                                                   | 0/484 [00:00<?, ?it/s]  [note] M4: no logprobs returned (cloud model).
#  57%|███████████████████████▏                 | 274/484 [35:12<26:35,  7.60s/it]^C
#  57%|███████████████████████▏                 | 274/484 [35:13<27:00,  7.71s/it]
#
# [main/M4] Interrupted - saving progress...
# [main/M4] Done. 274 rows -> /home/taseen06/Desktop/R2/raw_outputs/r2_raw_main_M4.csv
# --- [main/M5] nemotron-3-super:cloud: 484 prompts to collect ---
#   0%|                                                   | 0/484 [00:00<?, ?it/s]

# %%
# !python '02_collect_api_data.py'
# Out:
# [main/M1] Resuming - 484 already collected.
# --- [main/M1] gemma3:27b-cloud: 0 prompts to collect ---
# 0it [00:00, ?it/s]
# [main/M1] Done. 484 rows -> /home/taseen06/Desktop/R2/raw_outputs/r2_raw_main_M1.csv
# [main/M2] Resuming - 484 already collected.
# --- [main/M2] gemma4:31b-cloud: 0 prompts to collect ---
# 0it [00:00, ?it/s]
# [main/M2] Done. 484 rows -> /home/taseen06/Desktop/R2/raw_outputs/r2_raw_main_M2.csv
# [main/M3] Resuming - 484 already collected.
# --- [main/M3] gpt-oss:120b-cloud: 0 prompts to collect ---
# 0it [00:00, ?it/s]
# [main/M3] Done. 484 rows -> /home/taseen06/Desktop/R2/raw_outputs/r2_raw_main_M3.csv
# [main/M4] Resuming - 274 already collected.
# --- [main/M4] qwen3-next:80b-cloud: 210 prompts to collect ---
#   0%|                                                   | 0/210 [00:00<?, ?it/s]  [note] M4: no logprobs returned (cloud model).
# 100%|█████████████████████████████████████████| 210/210 [22:30<00:00,  6.43s/it]
# [main/M4] Done. 484 rows -> /home/taseen06/Desktop/R2/raw_outputs/r2_raw_main_M4.csv
# --- [main/M5] nemotron-3-super:cloud: 484 prompts to collect ---
#   0%|                                                   | 0/484 [00:00<?, ?it/s]  [note] M5: no logprobs returned (cloud model).
# 100%|█████████████████████████████████████████| 484/484 [39:27<00:00,  4.89s/it]
# [main/M5] Done. 484 rows -> /home/taseen06/Desktop/R2/raw_outputs/r2_raw_main_M5.csv

# %%
# !python '02_collect_api_data.py'
# Out:
# [main/M1] Resuming - 484 already collected.
# --- [main/M1] gemma3:27b-cloud: 0 prompts to collect ---
# 0it [00:00, ?it/s]
# [main/M1] Done. 484 rows -> /home/taseen06/Desktop/R2/raw_outputs/r2_raw_main_M1.csv
# [main/M2] Resuming - 484 already collected.
# --- [main/M2] gemma4:31b-cloud: 0 prompts to collect ---
# 0it [00:00, ?it/s]
# [main/M2] Done. 484 rows -> /home/taseen06/Desktop/R2/raw_outputs/r2_raw_main_M2.csv
# [main/M3] Resuming - 484 already collected.
# --- [main/M3] gpt-oss:120b-cloud: 0 prompts to collect ---
# 0it [00:00, ?it/s]
# [main/M3] Done. 484 rows -> /home/taseen06/Desktop/R2/raw_outputs/r2_raw_main_M3.csv
# [main/M4] Resuming - 484 already collected.
# --- [main/M4] qwen3-next:80b-cloud: 0 prompts to collect ---
# 0it [00:00, ?it/s]
# [main/M4] Done. 484 rows -> /home/taseen06/Desktop/R2/raw_outputs/r2_raw_main_M4.csv
# [main/M5] Resuming - 484 already collected.
# --- [main/M5] nemotron-3-super:cloud: 0 prompts to collect ---
# 0it [00:00, ?it/s]
# [main/M5] Done. 484 rows -> /home/taseen06/Desktop/R2/raw_outputs/r2_raw_main_M5.csv

# %%
# !python 02_collect_api_data.py --input probes_demographic.csv --tag demo

# !python 02_collect_api_data.py --input probes_authority.csv --tag auth

# !python 02_collect_api_data.py --input probes_safety.csv --tag safety
# Out:
# --- [demo/M1] gemma3:27b-cloud: 240 prompts to collect ---
#   0%|                                                   | 0/240 [00:00<?, ?it/s]  [note] M1: no logprobs returned (cloud model).
# 100%|█████████████████████████████████████████| 240/240 [16:19<00:00,  4.08s/it]
# [demo/M1] Done. 240 rows -> /home/taseen06/Desktop/R2/raw_outputs/r2_raw_demo_M1.csv
# --- [demo/M2] gemma4:31b-cloud: 240 prompts to collect ---
#   0%|                                                   | 0/240 [00:00<?, ?it/s]  [note] M2: no logprobs returned (cloud model).
# 100%|█████████████████████████████████████████| 240/240 [15:00<00:00,  3.75s/it]
# [demo/M2] Done. 240 rows -> /home/taseen06/Desktop/R2/raw_outputs/r2_raw_demo_M2.csv
# --- [demo/M3] gpt-oss:120b-cloud: 240 prompts to collect ---
#   0%|                                                   | 0/240 [00:00<?, ?it/s]  [note] M3: no logprobs returned (cloud model).
# 100%|█████████████████████████████████████████| 240/240 [15:39<00:00,  3.91s/it]
# [demo/M3] Done. 240 rows -> /home/taseen06/Desktop/R2/raw_outputs/r2_raw_demo_M3.csv
# --- [demo/M4] qwen3-next:80b-cloud: 240 prompts to collect ---
#   0%|                                                   | 0/240 [00:00<?, ?it/s]  [note] M4: no logprobs returned (cloud model).
#  84%|████████████████████████████████▋      | 201/240 [1:00:31<37:02, 56.98s/it]^C
#  84%|████████████████████████████████▋      | 201/240 [1:01:40<11:57, 18.41s/it]
#
# [demo/M4] Interrupted - saving progress...
# [demo/M4] Done. 201 rows -> /home/taseen06/Desktop/R2/raw_outputs/r2_raw_demo_M4.csv
# --- [demo/M5] nemotron-3-super:cloud: 240 prompts to collect ---
#   0%|                                                   | 0/240 [00:00<?, ?it/s]--- [auth/M1] gemma3:27b-cloud: 200 prompts to collect ---
#   0%|                                                   | 0/200 [00:00<?, ?it/s]  [note] M1: no logprobs returned (cloud model).
#   0%|▏                                          | 1/200 [00:04<13:44,  4.14s/it]^C
#   0%|▏                                          | 1/200 [00:05<17:04,  5.15s/it]
#
# [auth/M1] Interrupted - saving progress...
# [auth/M1] Done. 1 rows -> /home/taseen06/Desktop/R2/raw_outputs/r2_raw_auth_M1.csv
# --- [auth/M2] gemma4:31b-cloud: 200 prompts to collect ---
#   0%|                                                   | 0/200 [00:00<?, ?it/s]--- [safety/M1] gemma3:27b-cloud: 200 prompts to collect ---
#   0%|                                                   | 0/200 [00:00<?, ?it/s]  [note] M1: no logprobs returned (cloud model).
#   0%|▏                                          | 1/200 [00:05<19:18,  5.82s/it]^C
#   0%|▏                                          | 1/200 [00:07<24:33,  7.40s/it]
#
# [safety/M1] Interrupted - saving progress...
# [safety/M1] Done. 1 rows -> /home/taseen06/Desktop/R2/raw_outputs/r2_raw_safety_M1.csv
# --- [safety/M2] gemma4:31b-cloud: 200 prompts to collect ---
#   0%|                                                   | 0/200 [00:00<?, ?it/s]

# %%
# !python 02_collect_api_data.py --input probes_demographic.csv --tag demo

# !python 02_collect_api_data.py --input probes_authority.csv --tag auth

# !python 02_collect_api_data.py --input probes_safety.csv --tag safety
# Out:
# [demo/M1] Resuming - 240 already collected.
# --- [demo/M1] gemma3:27b-cloud: 0 prompts to collect ---
# 0it [00:00, ?it/s]
# [demo/M1] Done. 240 rows -> /home/taseen06/Desktop/R2/raw_outputs/r2_raw_demo_M1.csv
# [demo/M2] Resuming - 240 already collected.
# --- [demo/M2] gemma4:31b-cloud: 0 prompts to collect ---
# 0it [00:00, ?it/s]
# [demo/M2] Done. 240 rows -> /home/taseen06/Desktop/R2/raw_outputs/r2_raw_demo_M2.csv
# [demo/M3] Resuming - 240 already collected.
# --- [demo/M3] gpt-oss:120b-cloud: 0 prompts to collect ---
# 0it [00:00, ?it/s]
# [demo/M3] Done. 240 rows -> /home/taseen06/Desktop/R2/raw_outputs/r2_raw_demo_M3.csv
# [demo/M4] Resuming - 201 already collected.
# --- [demo/M4] qwen3-next:80b-cloud: 39 prompts to collect ---
#   0%|                                                    | 0/39 [00:00<?, ?it/s]  [note] M4: no logprobs returned (cloud model).
# 100%|███████████████████████████████████████████| 39/39 [10:14<00:00, 15.77s/it]
# [demo/M4] Done. 240 rows -> /home/taseen06/Desktop/R2/raw_outputs/r2_raw_demo_M4.csv
# --- [demo/M5] nemotron-3-super:cloud: 240 prompts to collect ---
#   0%|                                                   | 0/240 [00:00<?, ?it/s]  [note] M5: no logprobs returned (cloud model).
#  39%|████████████████▍                         | 94/240 [05:48<08:55,  3.67s/it]

# %%
# !python 02_collect_api_data.py --input probes_demographic.csv --tag demo

# !python 02_collect_api_data.py --input probes_authority.csv --tag auth

# !python 02_collect_api_data.py --input probes_safety.csv --tag safety
# Out:
# [demo/M1] Resuming - 240 already collected.
# --- [demo/M1] gemma3:27b-cloud: 0 prompts to collect ---
# 0it [00:00, ?it/s]
# [demo/M1] Done. 240 rows -> /home/taseen06/Desktop/R2/raw_outputs/r2_raw_demo_M1.csv
# [demo/M2] Resuming - 240 already collected.
# --- [demo/M2] gemma4:31b-cloud: 0 prompts to collect ---
# 0it [00:00, ?it/s]
# [demo/M2] Done. 240 rows -> /home/taseen06/Desktop/R2/raw_outputs/r2_raw_demo_M2.csv
# [demo/M3] Resuming - 240 already collected.
# --- [demo/M3] gpt-oss:120b-cloud: 0 prompts to collect ---
# 0it [00:00, ?it/s]
# [demo/M3] Done. 240 rows -> /home/taseen06/Desktop/R2/raw_outputs/r2_raw_demo_M3.csv
# [demo/M4] Resuming - 240 already collected.
# --- [demo/M4] qwen3-next:80b-cloud: 0 prompts to collect ---
# 0it [00:00, ?it/s]
# [demo/M4] Done. 240 rows -> /home/taseen06/Desktop/R2/raw_outputs/r2_raw_demo_M4.csv
# [demo/M5] Resuming - 100 already collected.
# --- [demo/M5] nemotron-3-super:cloud: 140 prompts to collect ---
#   0%|                                                   | 0/140 [00:00<?, ?it/s]  [note] M5: no logprobs returned (cloud model).
# 100%|█████████████████████████████████████████| 140/140 [12:07<00:00,  5.19s/it]
# [demo/M5] Done. 240 rows -> /home/taseen06/Desktop/R2/raw_outputs/r2_raw_demo_M5.csv
# [auth/M1] Resuming - 1 already collected.
# --- [auth/M1] gemma3:27b-cloud: 199 prompts to collect ---
#   0%|                                                   | 0/199 [00:00<?, ?it/s]  [note] M1: no logprobs returned (cloud model).
# 100%|█████████████████████████████████████████| 199/199 [22:31<00:00,  6.79s/it]
# [auth/M1] Done. 200 rows -> /home/taseen06/Desktop/R2/raw_outputs/r2_raw_auth_M1.csv
# --- [auth/M2] gemma4:31b-cloud: 200 prompts to collect ---
#   0%|                                                   | 0/200 [00:00<?, ?it/s]  [note] M2: no logprobs returned (cloud model).
# 100%|█████████████████████████████████████████| 200/200 [33:14<00:00,  9.97s/it]
# [auth/M2] Done. 200 rows -> /home/taseen06/Desktop/R2/raw_outputs/r2_raw_auth_M2.csv
# --- [auth/M3] gpt-oss:120b-cloud: 200 prompts to collect ---
#   0%|                                                   | 0/200 [00:00<?, ?it/s]  [note] M3: no logprobs returned (cloud model).
# 100%|█████████████████████████████████████████| 200/200 [27:23<00:00,  8.22s/it]
# [auth/M3] Done. 200 rows -> /home/taseen06/Desktop/R2/raw_outputs/r2_raw_auth_M3.csv
# --- [auth/M4] qwen3-next:80b-cloud: 200 prompts to collect ---
#   0%|                                                   | 0/200 [00:00<?, ?it/s]  [note] M4: no logprobs returned (cloud model).
# 100%|█████████████████████████████████████████| 200/200 [27:40<00:00,  8.30s/it]
# [auth/M4] Done. 200 rows -> /home/taseen06/Desktop/R2/raw_outputs/r2_raw_auth_M4.csv
# --- [auth/M5] nemotron-3-super:cloud: 200 prompts to collect ---
#   0%|                                                   | 0/200 [00:00<?, ?it/s]  [note] M5: no logprobs returned (cloud model).
#  10%|████▏                                     | 20/200 [02:05<20:33,  6.85s/it]^C
#  10%|████▏                                     | 20/200 [02:07<19:05,  6.36s/it]
#
# [auth/M5] Interrupted - saving progress...
# [auth/M5] Done. 20 rows -> /home/taseen06/Desktop/R2/raw_outputs/r2_raw_auth_M5.csv
# [safety/M1] Resuming - 1 already collected.
# --- [safety/M1] gemma3:27b-cloud: 199 prompts to collect ---
#   0%|                                                   | 0/199 [00:00<?, ?it/s]^C
#   0%|                                                   | 0/199 [00:01<?, ?it/s]
#
# [safety/M1] Interrupted - saving progress...
# [safety/M1] Done. 1 rows -> /home/taseen06/Desktop/R2/raw_outputs/r2_raw_safety_M1.csv
# --- [safety/M2] gemma4:31b-cloud: 200 prompts to collect ---
#   0%|                                                   | 0/200 [00:00<?, ?it/s]

# %%
# !python 02_collect_api_data.py --input probes_demographic.csv --tag demo

# !python 02_collect_api_data.py --input probes_authority.csv --tag auth

# !python 02_collect_api_data.py --input probes_safety.csv --tag safety
# Out:
# [demo/M1] Resuming - 240 already collected.
# --- [demo/M1] gemma3:27b-cloud: 0 prompts to collect ---
# 0it [00:00, ?it/s]
# [demo/M1] Done. 240 rows -> /home/taseen06/Desktop/R2/raw_outputs/r2_raw_demo_M1.csv
# [demo/M2] Resuming - 240 already collected.
# --- [demo/M2] gemma4:31b-cloud: 0 prompts to collect ---
# 0it [00:00, ?it/s]
# [demo/M2] Done. 240 rows -> /home/taseen06/Desktop/R2/raw_outputs/r2_raw_demo_M2.csv
# [demo/M3] Resuming - 240 already collected.
# --- [demo/M3] gpt-oss:120b-cloud: 0 prompts to collect ---
# 0it [00:00, ?it/s]
# [demo/M3] Done. 240 rows -> /home/taseen06/Desktop/R2/raw_outputs/r2_raw_demo_M3.csv
# [demo/M4] Resuming - 240 already collected.
# --- [demo/M4] qwen3-next:80b-cloud: 0 prompts to collect ---
# 0it [00:00, ?it/s]
# [demo/M4] Done. 240 rows -> /home/taseen06/Desktop/R2/raw_outputs/r2_raw_demo_M4.csv
# [demo/M5] Resuming - 240 already collected.
# --- [demo/M5] nemotron-3-super:cloud: 0 prompts to collect ---
# 0it [00:00, ?it/s]
# [demo/M5] Done. 240 rows -> /home/taseen06/Desktop/R2/raw_outputs/r2_raw_demo_M5.csv
# [auth/M1] Resuming - 200 already collected.
# --- [auth/M1] gemma3:27b-cloud: 0 prompts to collect ---
# 0it [00:00, ?it/s]
# [auth/M1] Done. 200 rows -> /home/taseen06/Desktop/R2/raw_outputs/r2_raw_auth_M1.csv
# [auth/M2] Resuming - 200 already collected.
# --- [auth/M2] gemma4:31b-cloud: 0 prompts to collect ---
# 0it [00:00, ?it/s]
# [auth/M2] Done. 200 rows -> /home/taseen06/Desktop/R2/raw_outputs/r2_raw_auth_M2.csv
# [auth/M3] Resuming - 200 already collected.
# --- [auth/M3] gpt-oss:120b-cloud: 0 prompts to collect ---
# 0it [00:00, ?it/s]
# [auth/M3] Done. 200 rows -> /home/taseen06/Desktop/R2/raw_outputs/r2_raw_auth_M3.csv
# [auth/M4] Resuming - 200 already collected.
# --- [auth/M4] qwen3-next:80b-cloud: 0 prompts to collect ---
# 0it [00:00, ?it/s]
# [auth/M4] Done. 200 rows -> /home/taseen06/Desktop/R2/raw_outputs/r2_raw_auth_M4.csv
# [auth/M5] Resuming - 20 already collected.
# --- [auth/M5] nemotron-3-super:cloud: 180 prompts to collect ---
#   0%|                                                   | 0/180 [00:00<?, ?it/s]  [note] M5: no logprobs returned (cloud model).
# 100%|█████████████████████████████████████████| 180/180 [25:54<00:00,  8.64s/it]
# [auth/M5] Done. 200 rows -> /home/taseen06/Desktop/R2/raw_outputs/r2_raw_auth_M5.csv
# [safety/M1] Resuming - 1 already collected.
# --- [safety/M1] gemma3:27b-cloud: 199 prompts to collect ---
#   0%|                                                   | 0/199 [00:00<?, ?it/s]  [note] M1: no logprobs returned (cloud model).
# 100%|█████████████████████████████████████████| 199/199 [22:14<00:00,  6.71s/it]
# [safety/M1] Done. 200 rows -> /home/taseen06/Desktop/R2/raw_outputs/r2_raw_safety_M1.csv
# --- [safety/M2] gemma4:31b-cloud: 200 prompts to collect ---
#   0%|                                                   | 0/200 [00:00<?, ?it/s]  [note] M2: no logprobs returned (cloud model).
# 100%|█████████████████████████████████████████| 200/200 [53:02<00:00, 15.91s/it]
# [safety/M2] Done. 200 rows -> /home/taseen06/Desktop/R2/raw_outputs/r2_raw_safety_M2.csv
# --- [safety/M3] gpt-oss:120b-cloud: 200 prompts to collect ---
#   0%|                                                   | 0/200 [00:00<?, ?it/s]  [note] M3: no logprobs returned (cloud model).
# 100%|█████████████████████████████████████████| 200/200 [25:22<00:00,  7.61s/it]
# [safety/M3] Done. 200 rows -> /home/taseen06/Desktop/R2/raw_outputs/r2_raw_safety_M3.csv
# --- [safety/M4] qwen3-next:80b-cloud: 200 prompts to collect ---
#   0%|                                                   | 0/200 [00:00<?, ?it/s]  [note] M4: no logprobs returned (cloud model).
# 100%|█████████████████████████████████████████| 200/200 [28:16<00:00,  8.48s/it]
# [safety/M4] Done. 200 rows -> /home/taseen06/Desktop/R2/raw_outputs/r2_raw_safety_M4.csv
# --- [safety/M5] nemotron-3-super:cloud: 200 prompts to collect ---
#   0%|                                                   | 0/200 [00:00<?, ?it/s]  [note] M5: no logprobs returned (cloud model).
#  60%|████████████████████████▌                | 120/200 [15:21<09:04,  6.81s/it]^C
#  60%|████████████████████████▌                | 120/200 [15:26<10:17,  7.72s/it]
#
# [safety/M5] Interrupted - saving progress...
# [safety/M5] Done. 120 rows -> /home/taseen06/Desktop/R2/raw_outputs/r2_raw_safety_M5.csv

# %%
# !python 02_collect_api_data.py --input probes_demographic.csv --tag demo

# !python 02_collect_api_data.py --input probes_authority.csv --tag auth

# !python 02_collect_api_data.py --input probes_safety.csv --tag safety
# Out:
# [demo/M1] Resuming - 240 already collected.
# --- [demo/M1] gemma3:27b-cloud: 0 prompts to collect ---
# 0it [00:00, ?it/s]
# [demo/M1] Done. 240 rows -> /home/taseen06/Desktop/R2/raw_outputs/r2_raw_demo_M1.csv
# [demo/M2] Resuming - 240 already collected.
# --- [demo/M2] gemma4:31b-cloud: 0 prompts to collect ---
# 0it [00:00, ?it/s]
# [demo/M2] Done. 240 rows -> /home/taseen06/Desktop/R2/raw_outputs/r2_raw_demo_M2.csv
# [demo/M3] Resuming - 240 already collected.
# --- [demo/M3] gpt-oss:120b-cloud: 0 prompts to collect ---
# 0it [00:00, ?it/s]
# [demo/M3] Done. 240 rows -> /home/taseen06/Desktop/R2/raw_outputs/r2_raw_demo_M3.csv
# [demo/M4] Resuming - 240 already collected.
# --- [demo/M4] qwen3-next:80b-cloud: 0 prompts to collect ---
# 0it [00:00, ?it/s]
# [demo/M4] Done. 240 rows -> /home/taseen06/Desktop/R2/raw_outputs/r2_raw_demo_M4.csv
# [demo/M5] Resuming - 240 already collected.
# --- [demo/M5] nemotron-3-super:cloud: 0 prompts to collect ---
# 0it [00:00, ?it/s]
# [demo/M5] Done. 240 rows -> /home/taseen06/Desktop/R2/raw_outputs/r2_raw_demo_M5.csv
# [auth/M1] Resuming - 200 already collected.
# --- [auth/M1] gemma3:27b-cloud: 0 prompts to collect ---
# 0it [00:00, ?it/s]
# [auth/M1] Done. 200 rows -> /home/taseen06/Desktop/R2/raw_outputs/r2_raw_auth_M1.csv
# [auth/M2] Resuming - 200 already collected.
# --- [auth/M2] gemma4:31b-cloud: 0 prompts to collect ---
# 0it [00:00, ?it/s]
# [auth/M2] Done. 200 rows -> /home/taseen06/Desktop/R2/raw_outputs/r2_raw_auth_M2.csv
# [auth/M3] Resuming - 200 already collected.
# --- [auth/M3] gpt-oss:120b-cloud: 0 prompts to collect ---
# 0it [00:00, ?it/s]
# [auth/M3] Done. 200 rows -> /home/taseen06/Desktop/R2/raw_outputs/r2_raw_auth_M3.csv
# [auth/M4] Resuming - 200 already collected.
# --- [auth/M4] qwen3-next:80b-cloud: 0 prompts to collect ---
# 0it [00:00, ?it/s]
# [auth/M4] Done. 200 rows -> /home/taseen06/Desktop/R2/raw_outputs/r2_raw_auth_M4.csv
# [auth/M5] Resuming - 200 already collected.
# --- [auth/M5] nemotron-3-super:cloud: 0 prompts to collect ---
# 0it [00:00, ?it/s]
# [auth/M5] Done. 200 rows -> /home/taseen06/Desktop/R2/raw_outputs/r2_raw_auth_M5.csv
# [safety/M1] Resuming - 200 already collected.
# --- [safety/M1] gemma3:27b-cloud: 0 prompts to collect ---
# 0it [00:00, ?it/s]
# [safety/M1] Done. 200 rows -> /home/taseen06/Desktop/R2/raw_outputs/r2_raw_safety_M1.csv
# [safety/M2] Resuming - 200 already collected.
# --- [safety/M2] gemma4:31b-cloud: 0 prompts to collect ---
# 0it [00:00, ?it/s]
# [safety/M2] Done. 200 rows -> /home/taseen06/Desktop/R2/raw_outputs/r2_raw_safety_M2.csv
# [safety/M3] Resuming - 200 already collected.
# --- [safety/M3] gpt-oss:120b-cloud: 0 prompts to collect ---
# 0it [00:00, ?it/s]
# [safety/M3] Done. 200 rows -> /home/taseen06/Desktop/R2/raw_outputs/r2_raw_safety_M3.csv
# [safety/M4] Resuming - 200 already collected.
# --- [safety/M4] qwen3-next:80b-cloud: 0 prompts to collect ---
# 0it [00:00, ?it/s]
# [safety/M4] Done. 200 rows -> /home/taseen06/Desktop/R2/raw_outputs/r2_raw_safety_M4.csv
# [safety/M5] Resuming - 120 already collected.
# --- [safety/M5] nemotron-3-super:cloud: 80 prompts to collect ---
#   0%|                                                    | 0/80 [00:00<?, ?it/s]  [note] M5: no logprobs returned (cloud model).
# 100%|███████████████████████████████████████████| 80/80 [07:26<00:00,  5.58s/it]
# [safety/M5] Done. 200 rows -> /home/taseen06/Desktop/R2/raw_outputs/r2_raw_safety_M5.csv

# %%
# !python 02_collect_api_data.py --input probes_demographic.csv --tag demo

# !python 02_collect_api_data.py --input probes_authority.csv --tag auth

# !python 02_collect_api_data.py --input probes_safety.csv --tag safety
# Out:
# [demo/M1] Resuming - 240 already collected.
# --- [demo/M1] gemma3:27b-cloud: 0 prompts to collect ---
# 0it [00:00, ?it/s]
# [demo/M1] Done. 240 rows -> /home/taseen06/Desktop/R2/raw_outputs/r2_raw_demo_M1.csv
# [demo/M2] Resuming - 240 already collected.
# --- [demo/M2] gemma4:31b-cloud: 0 prompts to collect ---
# 0it [00:00, ?it/s]
# [demo/M2] Done. 240 rows -> /home/taseen06/Desktop/R2/raw_outputs/r2_raw_demo_M2.csv
# [demo/M3] Resuming - 240 already collected.
# --- [demo/M3] gpt-oss:120b-cloud: 0 prompts to collect ---
# 0it [00:00, ?it/s]
# [demo/M3] Done. 240 rows -> /home/taseen06/Desktop/R2/raw_outputs/r2_raw_demo_M3.csv
# [demo/M4] Resuming - 240 already collected.
# --- [demo/M4] qwen3-next:80b-cloud: 0 prompts to collect ---
# 0it [00:00, ?it/s]
# [demo/M4] Done. 240 rows -> /home/taseen06/Desktop/R2/raw_outputs/r2_raw_demo_M4.csv
# [demo/M5] Resuming - 240 already collected.
# --- [demo/M5] nemotron-3-super:cloud: 0 prompts to collect ---
# 0it [00:00, ?it/s]
# [demo/M5] Done. 240 rows -> /home/taseen06/Desktop/R2/raw_outputs/r2_raw_demo_M5.csv
# [auth/M1] Resuming - 200 already collected.
# --- [auth/M1] gemma3:27b-cloud: 0 prompts to collect ---
# 0it [00:00, ?it/s]
# [auth/M1] Done. 200 rows -> /home/taseen06/Desktop/R2/raw_outputs/r2_raw_auth_M1.csv
# [auth/M2] Resuming - 200 already collected.
# --- [auth/M2] gemma4:31b-cloud: 0 prompts to collect ---
# 0it [00:00, ?it/s]
# [auth/M2] Done. 200 rows -> /home/taseen06/Desktop/R2/raw_outputs/r2_raw_auth_M2.csv
# [auth/M3] Resuming - 200 already collected.
# --- [auth/M3] gpt-oss:120b-cloud: 0 prompts to collect ---
# 0it [00:00, ?it/s]
# [auth/M3] Done. 200 rows -> /home/taseen06/Desktop/R2/raw_outputs/r2_raw_auth_M3.csv
# [auth/M4] Resuming - 200 already collected.
# --- [auth/M4] qwen3-next:80b-cloud: 0 prompts to collect ---
# 0it [00:00, ?it/s]
# [auth/M4] Done. 200 rows -> /home/taseen06/Desktop/R2/raw_outputs/r2_raw_auth_M4.csv
# [auth/M5] Resuming - 200 already collected.
# --- [auth/M5] nemotron-3-super:cloud: 0 prompts to collect ---
# 0it [00:00, ?it/s]
# [auth/M5] Done. 200 rows -> /home/taseen06/Desktop/R2/raw_outputs/r2_raw_auth_M5.csv
# [safety/M1] Resuming - 200 already collected.
# --- [safety/M1] gemma3:27b-cloud: 0 prompts to collect ---
# 0it [00:00, ?it/s]
# [safety/M1] Done. 200 rows -> /home/taseen06/Desktop/R2/raw_outputs/r2_raw_safety_M1.csv
# [safety/M2] Resuming - 200 already collected.
# --- [safety/M2] gemma4:31b-cloud: 0 prompts to collect ---
# 0it [00:00, ?it/s]
# [safety/M2] Done. 200 rows -> /home/taseen06/Desktop/R2/raw_outputs/r2_raw_safety_M2.csv
# [safety/M3] Resuming - 200 already collected.
# --- [safety/M3] gpt-oss:120b-cloud: 0 prompts to collect ---
# 0it [00:00, ?it/s]
# [safety/M3] Done. 200 rows -> /home/taseen06/Desktop/R2/raw_outputs/r2_raw_safety_M3.csv
# [safety/M4] Resuming - 200 already collected.
# --- [safety/M4] qwen3-next:80b-cloud: 0 prompts to collect ---
# 0it [00:00, ?it/s]
# [safety/M4] Done. 200 rows -> /home/taseen06/Desktop/R2/raw_outputs/r2_raw_safety_M4.csv
# [safety/M5] Resuming - 200 already collected.
# --- [safety/M5] nemotron-3-super:cloud: 0 prompts to collect ---
# 0it [00:00, ?it/s]
# [safety/M5] Done. 200 rows -> /home/taseen06/Desktop/R2/raw_outputs/r2_raw_safety_M5.csv
