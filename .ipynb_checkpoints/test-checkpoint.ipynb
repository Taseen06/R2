# %%
# !python '01_sample_benchmarks.py'
# Out:
# Using the latest cached version of the dataset since trivia_qa couldn't be found on the Hugging Face Hub
# Found the latest cached dataset configuration 'rc.nocontext' at /home/taseen06/.cache/huggingface/datasets/trivia_qa/rc.nocontext/0.0.0/0f7faf33a3908546c6fd5b73a660e0f8ff173c2f (last modified on Mon May 25 12:48:23 2026).
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# Using the latest cached version of the dataset since truthful_qa couldn't be found on the Hugging Face Hub
# Found the latest cached dataset configuration 'generation' at /home/taseen06/.cache/huggingface/datasets/truthful_qa/generation/0.0.0/741b8276f2d1982aa3d5b832d3ee81ed3b896490 (last modified on Mon May 25 12:48:41 2026).
# prompts_main.csv: 600 rows | 300 ambiguous rows NEED Sadi's review
# probes written: demographic 240 | authority 200 | safety 200
# NEXT: Sadi hand-writes/reviews all needs_review=1 ambiguous prompts (incl. opinion C6).

# %%
with open('01_sample_benchmarks.py', encoding='utf-8') as f:
    exec(f.read())
# Out:
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# Using the latest cached version of the dataset since trivia_qa couldn't be found on the Hugging Face Hub
# Found the latest cached dataset configuration 'rc.nocontext' at /home/taseen06/.cache/huggingface/datasets/trivia_qa/rc.nocontext/0.0.0/0f7faf33a3908546c6fd5b73a660e0f8ff173c2f (last modified on Mon May 25 12:48:23 2026).
# Using the latest cached version of the dataset since truthful_qa couldn't be found on the Hugging Face Hub
# Found the latest cached dataset configuration 'generation' at /home/taseen06/.cache/huggingface/datasets/truthful_qa/generation/0.0.0/741b8276f2d1982aa3d5b832d3ee81ed3b896490 (last modified on Mon May 25 12:48:41 2026).
# prompts_main.csv: 600 rows | 300 ambiguous rows NEED Sadi's review
# probes written: demographic 240 | authority 200 | safety 200
# NEXT: Sadi hand-writes/reviews all needs_review=1 ambiguous prompts (incl. opinion C6).

# %%
# !python '02_collect_api_data.py'
# Out:
# --- [main/M1] gemma3:27b-cloud: 600 prompts to collect ---
#   0%|                                                   | 0/600 [00:00<?, ?it/s]  [note] M1: no logprobs returned (cloud model).
# 100%|█████████████████████████████████████████| 600/600 [46:05<00:00,  4.61s/it]
# [main/M1] Done. 600 rows -> /home/taseen06/Desktop/R2/raw_outputs/r2_raw_main_M1.csv
# --- [main/M2] gemma4:31b-cloud: 600 prompts to collect ---
#   0%|                                                   | 0/600 [00:00<?, ?it/s]  [note] M2: no logprobs returned (cloud model).
# 100%|███████████████████████████████████████| 600/600 [1:24:02<00:00,  8.40s/it]
# [main/M2] Done. 600 rows -> /home/taseen06/Desktop/R2/raw_outputs/r2_raw_main_M2.csv
# --- [main/M3] gpt-oss:120b-cloud: 600 prompts to collect ---
#   0%|                                                   | 0/600 [00:00<?, ?it/s]  [note] M3: no logprobs returned (cloud model).
# 100%|███████████████████████████████████████| 600/600 [1:03:16<00:00,  6.33s/it]
# [main/M3] Done. 600 rows -> /home/taseen06/Desktop/R2/raw_outputs/r2_raw_main_M3.csv
# --- [main/M4] qwen3-next:80b-cloud: 600 prompts to collect ---
#   0%|                                                   | 0/600 [00:00<?, ?it/s]  [note] M4: no logprobs returned (cloud model).
#  34%|█████████████                          | 201/600 [38:04<1:24:10, 12.66s/it]^C
#  34%|█████████████                          | 201/600 [38:04<1:15:35, 11.37s/it]
#
# [main/M4] Interrupted - saving progress...
# [main/M4] Done. 201 rows -> /home/taseen06/Desktop/R2/raw_outputs/r2_raw_main_M4.csv
# --- [main/M5] nemotron-3-super:cloud: 600 prompts to collect ---
#   0%|                                                   | 0/600 [00:00<?, ?it/s]

# %%
# !python '02_collect_api_data.py'
# Out:
# [main/M1] Resuming - 600 already collected.
# --- [main/M1] gemma3:27b-cloud: 0 prompts to collect ---
# 0it [00:00, ?it/s]
# [main/M1] Done. 600 rows -> /home/taseen06/Desktop/R2/raw_outputs/r2_raw_main_M1.csv
# [main/M2] Resuming - 600 already collected.
# --- [main/M2] gemma4:31b-cloud: 0 prompts to collect ---
# 0it [00:00, ?it/s]
# [main/M2] Done. 600 rows -> /home/taseen06/Desktop/R2/raw_outputs/r2_raw_main_M2.csv
# [main/M3] Resuming - 600 already collected.
# --- [main/M3] gpt-oss:120b-cloud: 0 prompts to collect ---
# 0it [00:00, ?it/s]
# [main/M3] Done. 600 rows -> /home/taseen06/Desktop/R2/raw_outputs/r2_raw_main_M3.csv
# [main/M4] Resuming - 201 already collected.
# --- [main/M4] qwen3-next:80b-cloud: 399 prompts to collect ---
#   0%|                                                   | 0/399 [00:00<?, ?it/s]  [note] M4: no logprobs returned (cloud model).
#  75%|█████████████████████████████▏         | 299/399 [1:12:22<13:27,  8.07s/it]^C
#  75%|█████████████████████████████▏         | 299/399 [1:12:24<24:13, 14.53s/it]
#
# [main/M4] Interrupted - saving progress...
# [main/M4] Done. 500 rows -> /home/taseen06/Desktop/R2/raw_outputs/r2_raw_main_M4.csv
# --- [main/M5] nemotron-3-super:cloud: 600 prompts to collect ---
#   0%|                                                   | 0/600 [00:00<?, ?it/s]

# %%
# !python '02_collect_api_data.py'
# Out:
# [main/M1] Resuming - 600 already collected.
# --- [main/M1] gemma3:27b-cloud: 0 prompts to collect ---
# 0it [00:00, ?it/s]
# [main/M1] Done. 600 rows -> /home/taseen06/Desktop/R2/raw_outputs/r2_raw_main_M1.csv
# [main/M2] Resuming - 600 already collected.
# --- [main/M2] gemma4:31b-cloud: 0 prompts to collect ---
# 0it [00:00, ?it/s]
# [main/M2] Done. 600 rows -> /home/taseen06/Desktop/R2/raw_outputs/r2_raw_main_M2.csv
# [main/M3] Resuming - 600 already collected.
# --- [main/M3] gpt-oss:120b-cloud: 0 prompts to collect ---
# 0it [00:00, ?it/s]
# [main/M3] Done. 600 rows -> /home/taseen06/Desktop/R2/raw_outputs/r2_raw_main_M3.csv
# [main/M4] Resuming - 500 already collected.
# --- [main/M4] qwen3-next:80b-cloud: 100 prompts to collect ---
#   0%|                                                   | 0/100 [00:00<?, ?it/s]  [note] M4: no logprobs returned (cloud model).
# 100%|█████████████████████████████████████████| 100/100 [15:00<00:00,  9.01s/it]
# [main/M4] Done. 600 rows -> /home/taseen06/Desktop/R2/raw_outputs/r2_raw_main_M4.csv
# --- [main/M5] nemotron-3-super:cloud: 600 prompts to collect ---
#   0%|                                                   | 0/600 [00:00<?, ?it/s]  [note] M5: no logprobs returned (cloud model).
# 100%|███████████████████████████████████████| 600/600 [1:20:30<00:00,  8.05s/it]
# [main/M5] Done. 600 rows -> /home/taseen06/Desktop/R2/raw_outputs/r2_raw_main_M5.csv
