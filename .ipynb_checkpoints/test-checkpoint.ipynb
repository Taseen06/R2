# %%
# !python '01_sample_benchmarks.py'
# Out:
# Using the latest cached version of the dataset since trivia_qa couldn't be found on the Hugging Face Hub
# Found the latest cached dataset configuration 'rc.nocontext' at /home/taseen06/.cache/huggingface/datasets/trivia_qa/rc.nocontext/0.0.0/0f7faf33a3908546c6fd5b73a660e0f8ff173c2f (last modified on Mon May 25 12:48:23 2026).
# ...
# Using the latest cached version of the dataset since truthful_qa couldn't be found on the Hugging Face Hub
# Found the latest cached dataset configuration 'generation' at /home/taseen06/.cache/huggingface/datasets/truthful_qa/generation/0.0.0/741b8276f2d1982aa3d5b832d3ee81ed3b896490 (last modified on Mon May 25 12:48:41 2026).
# prompts_main.csv: 420 rows (210 ambiguous drafts need Sadi's review)
# probe files written. NEXT: Sadi reviews ambiguous drafts + expands opinion/probe seeds.

# %%
with open('01_sample_benchmarks.py', encoding='utf-8') as f:
    exec(f.read())
# Out:
# ...
# Using the latest cached version of the dataset since trivia_qa couldn't be found on the Hugging Face Hub
# Found the latest cached dataset configuration 'rc.nocontext' at /home/taseen06/.cache/huggingface/datasets/trivia_qa/rc.nocontext/0.0.0/0f7faf33a3908546c6fd5b73a660e0f8ff173c2f (last modified on Mon May 25 12:48:23 2026).
# Using the latest cached version of the dataset since truthful_qa couldn't be found on the Hugging Face Hub
# Found the latest cached dataset configuration 'generation' at /home/taseen06/.cache/huggingface/datasets/truthful_qa/generation/0.0.0/741b8276f2d1982aa3d5b832d3ee81ed3b896490 (last modified on Mon May 25 12:48:41 2026).
# prompts_main.csv: 420 rows (210 ambiguous drafts need Sadi's review)
# probe files written. NEXT: Sadi reviews ambiguous drafts + expands opinion/probe seeds.

# %%
# !python '02_collect_api_data.py'
# Out:
# --- [main/M1] gemma3:27b-cloud: 420 prompts to collect ---
# ...
# 100%|█████████████████████████████████████████| 420/420 [27:47<00:00,  3.97s/it]
# [main/M1] Done. 420 rows -> /home/taseen06/Desktop/R2/raw_outputs/r2_raw_main_M1.csv
# --- [main/M2] gemma4:31b-cloud: 420 prompts to collect ---
# ...
# 100%|█████████████████████████████████████████| 420/420 [38:21<00:00,  5.48s/it]
# [main/M2] Done. 420 rows -> /home/taseen06/Desktop/R2/raw_outputs/r2_raw_main_M2.csv
# --- [main/M3] gpt-oss:120b-cloud: 420 prompts to collect ---
# ...
# 100%|█████████████████████████████████████████| 420/420 [37:57<00:00,  5.42s/it]
# [main/M3] Done. 420 rows -> /home/taseen06/Desktop/R2/raw_outputs/r2_raw_main_M3.csv
# --- [main/M4] qwen3-next:80b-cloud: 420 prompts to collect ---
# ...
# 100%|███████████████████████████████████████| 420/420 [1:11:09<00:00, 10.17s/it]
# [main/M4] Done. 420 rows -> /home/taseen06/Desktop/R2/raw_outputs/r2_raw_main_M4.csv
# --- [main/M5] nemotron-3-super:cloud: 420 prompts to collect ---
# ...

# %%
# !python '02_collect_api_data.py'
# Out:
# [main/M1] Resuming - 420 already collected.
# --- [main/M1] gemma3:27b-cloud: 0 prompts to collect ---
# 0it [00:00, ?it/s]
# [main/M1] Done. 420 rows -> /home/taseen06/Desktop/R2/raw_outputs/r2_raw_main_M1.csv
# [main/M2] Resuming - 420 already collected.
# --- [main/M2] gemma4:31b-cloud: 0 prompts to collect ---
# 0it [00:00, ?it/s]
# [main/M2] Done. 420 rows -> /home/taseen06/Desktop/R2/raw_outputs/r2_raw_main_M2.csv
# [main/M3] Resuming - 420 already collected.
# --- [main/M3] gpt-oss:120b-cloud: 0 prompts to collect ---
# 0it [00:00, ?it/s]
# [main/M3] Done. 420 rows -> /home/taseen06/Desktop/R2/raw_outputs/r2_raw_main_M3.csv
# --- [main/M4] qwen3-next:80b-cloud: 420 prompts to collect ---
# ...
#  55%|██████████████████████▍                  | 230/420 [39:52<32:56, 10.40s/it]
#
# [main/M4] Interrupted - saving progress...
# [main/M4] Done. 230 rows -> /home/taseen06/Desktop/R2/raw_outputs/r2_raw_main_M4.csv
# --- [main/M5] nemotron-3-super:cloud: 420 prompts to collect ---
# ...

# %%
# !python '02_collect_api_data.py'
# Out:
# [main/M1] Resuming - 420 already collected.
# --- [main/M1] gemma3:27b-cloud: 0 prompts to collect ---
# 0it [00:00, ?it/s]
# [main/M1] Done. 420 rows -> /home/taseen06/Desktop/R2/raw_outputs/r2_raw_main_M1.csv
# [main/M2] Resuming - 420 already collected.
# --- [main/M2] gemma4:31b-cloud: 0 prompts to collect ---
# 0it [00:00, ?it/s]
# [main/M2] Done. 420 rows -> /home/taseen06/Desktop/R2/raw_outputs/r2_raw_main_M2.csv
# [main/M3] Resuming - 420 already collected.
# --- [main/M3] gpt-oss:120b-cloud: 0 prompts to collect ---
# 0it [00:00, ?it/s]
# [main/M3] Done. 420 rows -> /home/taseen06/Desktop/R2/raw_outputs/r2_raw_main_M3.csv
# [main/M4] Resuming - 230 already collected.
# --- [main/M4] qwen3-next:80b-cloud: 190 prompts to collect ---
# ...
#  26%|██████████▊                               | 49/190 [06:38<29:34, 12.59s/it]
